# %% [markdown]
# <a href="https://colab.research.google.com/github/ejtehadi/CompPhysIISQU/blob/Lecture-1/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # test print

# %%
2+2
# Out:
# 4

# %%
x = [1, 2, "test"]
print(x)
# Out:
# [1, 2, 'test']
